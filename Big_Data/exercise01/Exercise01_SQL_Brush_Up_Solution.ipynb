# %% [markdown]
# # <center>Big Data &ndash; Exercise 1 &ndash; Solution</center>
# ## <center>Fall 2021 &ndash; Week 2 &ndash; ETH Zurich</center>

# %% [markdown]
# ### Aims
# - **After this exercise:** Understand the SQL language and its common query patterns.
# - **Later in the semester:** Relate these language features and query patterns relative to other data shapes, technologies, and the languages designed to query them.
#
#
#
# - **After this exercise:** Understand the 'table' data shape, normalization, and when they can (and should) be used.
# - **Later in the semester:** Understand when you can (and should) throw all of this away!

# %% [markdown]
# ### Prerequisites
# In this exercise, you will brush-up the fundamental concepts of relational databases and SQL. If you haven't taken an introductory databases course (or want to refresh your knowledge) we recommend you to read the following:
#
# Garcia-Molina, Ullman, Widom: Database Systems: The Complete Book. Pearson, 2. Edition, 2008. (Chapters 1, 2, 3, and 6) [Available in the ETH Library] [[Online]](https://ebookcentral.proquest.com/lib/ethz/detail.action?pq-origsite=primo&docID=5832965) [[Selected solutions]](http://infolab.stanford.edu/~ullman/dscbsols/sols.html)

# %% [markdown]
# ### Database Set-up
# Unlike last week's exercise, the dataset for this exercise might take a little bit longer to download and initialize. Please wait for the message `PostgreSQL init process complete; ready for start up` in the docker logs  before proceeding!
#
# As before, we set up our connection to the database and enable use of `%sql` and `%%sql`.

# %%
server='postgres'
user='postgres'
password='BigData1'
database='discogs'
connection_string=f'postgresql://{user}:{password}@{server}:5432/{database}'

# %%
# %reload_ext sql
# %sql $connection_string

# %%
# %%sql
# SELECT version();
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 1 rows affected.
# [('PostgreSQL 14.5 (Debian 14.5-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit',)]

# %% [markdown]
# ## Exercise 1: Explore the dataset
# We want to first understand the dataset a bit better. You will find some queries below to help you explore the schema. In the process, consider the following questions:
#
# 1. Which concepts are modelled in the dataset and how do they relate to each other?
# 2. The data is stored as tables. Why was this shape chosen and why not the other shapes?
# 3. In which normal forms are the corresponding relations?
# 4. What are the efficiency trade-offs from adding an `artist_id` and `artist_name` directly to the `releases` table? Hints:
#    - What are some typical queries that would benefit from this change?
#    - How often do we need to update artists?
# 5. What potential problems could result from adding this redundancy?
#
# ### Where we got the data from
# - [Discogs](https://www.discogs.com/)
# - [Discogs XML data dumps](http://data.discogs.com/)
# - [Download the dataset](https://cloud.inf.ethz.ch/s/DtjCHTLRHT39BRN/download/discogs.dump.xz) (only necessary if you don't want to use Docker, see `postgres-init.sh` to see how to import it)
#
# ### List tables
# The following query retrieves a list of tables in the database from a system table describing the current database.

# %%
# %%sql
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'public';
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 4 rows affected.
# [('artists',), ('released_by',), ('releases',), ('tracks',)]

# %% [markdown]
# ### List attributes/columns
# The following query retrieves a list of columns from the tables in the database.

# %%
# %%sql
# SELECT table_name, column_name, data_type, is_nullable, ordinal_position
# FROM information_schema.columns
# WHERE table_schema = 'public'
# AND table_name NOT LIKE 'pg_%'
# ORDER BY table_name, ordinal_position;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 17 rows affected.
# [('artists', 'artist_id', 'integer', 'NO', 1),
#  ('artists', 'name', 'character varying', 'YES', 2),
#  ('artists', 'realname', 'text', 'YES', 3),
#  ('artists', 'profile', 'text', 'YES', 4),
#  ('artists', 'url', 'text', 'YES', 5),
#  ('released_by', 'release_id', 'integer', 'NO', 1),
#  ('released_by', 'artist_id', 'integer', 'NO', 2),
#  ('releases', 'release_id', 'integer', 'NO', 1),
#  ('releases', 'released', 'date', 'NO', 2),
#  ('releases', 'title', 'text', 'NO', 3),
#  ('releases', 'country', 'character varying', 'YES', 4),
#  ('releases', 'genre', 'character varying', 'NO', 5),
#  ('tracks', 'release_id', 'integer', 'NO', 1),
#  ('tracks', 'position', 'character varying', 'YES', 2),
#  ('tracks', 'title', 'text', 'YES', 3),
#  ('tracks', 'duration', 'integer', 'YES', 4),
#  ('tracks', 'track_id', 'integer', 'NO', 5)]

# %% [markdown]
# ### Question 1

# %%
# %%sql
# select name
# count(name)
# from artists
# group by name
# limit 10
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# (psycopg2.errors.SyntaxError) syntax error at or near "("
# LINE 1: select name count(name) from artists
#                          ^
#
# [SQL: select name count(name) from artists
# group by name
# limit 10]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Exercise 1: Solution
# 1. Which concepts are modelled in the dataset and how do they relate to each other?
#
#    The dataset contains data from `discogs` and models musical artists, their physical releases, and the tracks on those releases.
#
# 2. The data is stored as tables. Why was this shape chosen and why not the other shapes?
#    - The number of concepts is limited, fixed, and well-defined.
#    - The same is true for attributes of these concepts.
#    - Attributes come from a well-defined domains with a fixed semantic (such as dates, e-mail addresses, ...).
#    - Instances of concepts are in relation with each other, which may or may not be required to exist.
#    - In short: we can define a schema, which the rest of the application (the website) relies on.
#
#
# 3. In which normal forms are the corresponding relations?
#
#    - All relations are atomic so they are in 1NF.
#    - `artists` and `releases` both have a singular ID primary key, so they at least 2NF. Upon inspection, there are no transitive dependencies, so they are in 3NF.
#    - `released_by` does not contain non-key attributes, so it is in 3NF.
#    - `tracks` has a foreign key constraint but no primary key constraint (although this is not captured by normal forms). The reason is likely because the data is crowd-sourced and archival, and there could be duplicate entries in the database.
#
#
# 4. What are the efficiency trade-offs from adding an `artist_id` and `artist_name` directly to the `releases` table? Hints:
#
#    - What are some typical queries that would benefit from this change?
#    - How often do we need to update artists?
#
#    A very typical query is finding all the releases by an artist's name. If we redundantly store the artist's ID and name in `releases`, the aforementioned query now only requires a `SELECT` instead of an expensive `JOIN`. As releases can be released by multiple artists, we could also extend this idea and break 1NF by storing a list of artist names instead. The tradeoff here is that every time we have to update an artist's name we have to find and update all releases by that artist. Considering that reads are very common and changes are rare, the option of denormalizing becomes relatively more attractive.
#
# 5. What potential problems could result from denormalizing the data?
#
#    - Insert anomaly: we could insert a release with a fake or incorrect artist name.
#    - Update anomaly: if we update an artist's name but not all of the records in `releases`, we introduce an inconsistency into the dataset.

# %% [markdown]
# ## Exercise 2: SQL warm-up
# Let us begin with several SQL queries to ease us back into the language.
#
# 1. Retrieve all artists with the name of 'Radiohead'.

# %%
# %%sql
# SELECT * FROM artists WHERE name = 'Radiohead';
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 1 rows affected.
# [(3840, 'Radiohead', None, 'Alternative Rock (Modern Rock) band from Oxfordshire, England (United Kingdom).\r \r The name Radiohead comes from the [a=Talking Heads] song, "Radio ... (2253 characters truncated) ...  [a=Pixies], [a=Magazine], [a=Joy Division], and [a=R.E.M.] (with lead singer of the band, Thom Yorke, refering to himself as an \'R.E.M. groupie\').', 'http://www.radiohead.com')]

# %% [markdown]
# 2. List the titles of all releases by that artist in alphabetical order.

# %%
# %%sql
# SELECT DISTINCT releases.title
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# WHERE artists.name = 'Radiohead'
# ORDER BY releases.title;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 61 rows affected.
# [('2+2=5',),
#  ('27 5 94 The Astoria London Live',),
#  ('7 Television Commercials',),
#  ('7 Television Commercials.',),
#  ('Airbag / How Am I Driving?',),
#  ('Ale To The Thieves',),
#  ('Amnesiac',),
#  ('Anyone Can Play Guitar',),
#  ('A Punchup At A Wedding',),
#  ('Beats And Breaks',),
#  ("Bizarre Love Triangle / Everything In Its Right Place (Nigel's Progressive House Mixes)",),
#  ('Climbing Up The Walls (Remixes)',),
#  ('Com Lag (2plus2isfive)',),
#  ('Creep',),
#  ('Deep In Velvet / Idioteque',),
#  ('Drill',),
#  ('Everything In Its Right Place (Aquasky Remix)',),
#  ('Everything In Its Right Place (House Mix)',),
#  ('Fake Plastic Trees',),
#  ('Go To Sleep',),
#  ('Go To Sleep (Zoo DJs Remix)',),
#  ('Greenhouse Effect Vs. Radiohead',),
#  ('Hail To The Thief',),
#  ('Hail To The Thief (Special Edition)',),
#  ('High & Dry',),
#  ('High & Dry / Planet Telex',),
#  ('Idioteque',),
#  ('I Might Be Wrong - Live Recordings',),
#  ('Interview CD',),
#  ('Itch',),
#  ('Just',),
#  ('Karma Police',),
#  ('Kid A',),
#  ('Kid A (Book And Compact Disc)',),
#  ('Knives Out',),
#  ('Knives Out / Cuttooth',),
#  ('Lucky',),
#  ('My Iron Lung',),
#  ('My Iron Lung E.P.',),
#  ('No Surprises',),
#  ('No Surprises / Running From Demons = ノーサプライゼス〜ランニング・フロム・ディーモンズ',),
#  ('OK Computer',),
#  ('Pablo Honey',),
#  ('Packt Like Sardines In A Crushd Tin Box (SM Remix)',),
#  ('Paranoid Android',),
#  ('Planet Telex',),
#  ('Pop Is Dead',),
#  ('Pyramid Song',),
#  ('Radiohead - In-Store Compilation',),
#  ('Remyxomatosis / Sktterbrain',),
#  ('Street Spirit',),
#  ('Street Spirit / Die Another Day',),
#  ('Street Spirit (Fade Out)',),
#  ('The Bends',),
#  ('The Bends T/W Edition',),
#  ('The Bends = ザ・ベンズ',),
#  ('The Gloaming (DJ Shadow Remix)',),
#  ('The Kid Parade',),
#  ('There There',),
#  ('The Right Place',),
#  ('Where I End And You Begin (2005 Club Mix)',)]

# %% [markdown]
# 3. List the titles of all releases by that artist that contain less than 5 tracks.

# %%
# %%sql
# SELECT releases.title, COUNT(*) AS num_tracks
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# JOIN tracks USING(release_id)
# WHERE artists.name = 'Radiohead'
# GROUP BY releases.release_id, releases.title
# HAVING COUNT(*) < 5;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 76 rows affected.
# [('Karma Police', 3),
#  ('Climbing Up The Walls (Remixes)', 2),
#  ('High & Dry / Planet Telex', 4),
#  ('Everything In Its Right Place (House Mix)', 1),
#  ('Planet Telex', 4),
#  ('Pyramid Song', 3),
#  ('Knives Out', 3),
#  ('Pyramid Song', 3),
#  ('Knives Out', 3),
#  ('Street Spirit', 1),
#  ('Packt Like Sardines In A Crushd Tin Box (SM Remix)', 1),
#  ('There There', 3),
#  ('Idioteque', 1),
#  ('Knives Out', 4),
#  ('There There', 3),
#  ('There There', 2),
#  ('Go To Sleep', 3),
#  ('Go To Sleep', 1),
#  ('Go To Sleep', 3),
#  ('Go To Sleep', 3),
#  ('High & Dry / Planet Telex', 4),
#  ('2+2=5', 1),
#  ('High & Dry / Planet Telex', 4),
#  ('Just', 3),
#  ('Knives Out / Cuttooth', 2),
#  ('Knives Out', 4),
#  ('Pyramid Song', 4),
#  ('Street Spirit (Fade Out)', 3),
#  ('Street Spirit (Fade Out)', 4),
#  ('No Surprises', 3),
#  ('Lucky', 3),
#  ('My Iron Lung', 4),
#  ('Fake Plastic Trees', 3),
#  ('Street Spirit (Fade Out)', 3),
#  ('2+2=5', 3),
#  ('2+2=5', 3),
#  ('2+2=5', 3),
#  ('A Punchup At A Wedding', 1),
#  ('Remyxomatosis / Sktterbrain', 2),
#  ('Go To Sleep', 3),
#  ('2+2=5', 3),
#  ('My Iron Lung E.P.', 4),
#  ('Go To Sleep', 3),
#  ('2+2=5', 3),
#  ('Go To Sleep (Zoo DJs Remix)', 1),
#  ('Knives Out', 3),
#  ('No Surprises', 3),
#  ('Pyramid Song', 3),
#  ('Street Spirit / Die Another Day', 2),
#  ("Bizarre Love Triangle / Everything In Its Right Place (Nigel's Progressive House Mixes)", 2),
#  ('The Gloaming (DJ Shadow Remix)', 2),
#  ('Go To Sleep', 3),
#  ('Creep', 4),
#  ('Paranoid Android', 2),
#  ('Pop Is Dead', 4),
#  ('Street Spirit (Fade Out)', 2),
#  ('No Surprises', 3),
#  ('The Right Place', 1),
#  ('Where I End And You Begin (2005 Club Mix)', 1),
#  ('Paranoid Android', 3),
#  ('Karma Police', 3),
#  ('There There', 2),
#  ('Knives Out', 1),
#  ('Ale To The Thieves', 3),
#  ('Creep', 4),
#  ('Creep', 4),
#  ('Creep', 4),
#  ('Anyone Can Play Guitar', 3),
#  ('Everything In Its Right Place (Aquasky Remix)', 1),
#  ('Paranoid Android', 3),
#  ('Paranoid Android', 3),
#  ('Karma Police', 3),
#  ('No Surprises', 3),
#  ('Fake Plastic Trees', 4),
#  ('Drill', 4),
#  ('Deep In Velvet / Idioteque', 2)]

# %% [markdown]
# 4. What are the top 10 artists with the most releases?

# %%
# %%sql
# SELECT artists.artist_id, artists.name, COUNT(*) AS num_releases
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# GROUP BY artists.artist_id, artists.name
# ORDER BY num_releases DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 10 rows affected.
# [(194, 'Various Artists', 46123),
#  (2725, 'Depeche Mode', 1053),
#  (8760, 'Madonna', 617),
#  (7552, 'Pet Shop Boys', 600),
#  (1031, 'Moby', 546),
#  (3909, 'New Order', 454),
#  (2714, 'Erasure', 448),
#  (28972, 'The Cure', 417),
#  (6520, 'U2', 365),
#  (66852, 'The Prodigy', 355)]

# %% [markdown]
# 5. How many artists have more releases than the average number of releases per artist?
#  SQL fnctional language so we feed result back in the next command

# %%
# %%sql
# WITH releases_per_artist AS (
#     SELECT artists.artist_id, artists.name, COUNT(*) AS release_count
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN releases USING(release_id)
#     GROUP BY artists.artist_id
# ),
# average_release_count AS (
#     SELECT AVG(release_count)
#     FROM releases_per_artist
# )
# SELECT COUNT(*)
# FROM releases_per_artist
# WHERE releases_per_artist.release_count > (SELECT * FROM average_release_count);
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 1 rows affected.
# [(23632,)]

# %% [markdown]
# 6. What are the names and IDs of the artists that have both a release with the genre 'Pop' *and* a release with the genre 'Classical'? Give a query that uses `INTERSECT` and one that uses `EXISTS`.

# %%
# %%sql
# SELECT artists.artist_id, artists.name
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# WHERE releases.genre = 'Pop'
# INTERSECT
# SELECT artists.artist_id, artists.name
# FROM artists
# JOIN released_by USING(artist_id)
# JOIN releases USING(release_id)
# WHERE releases.genre = 'Classical'
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 11 rows affected.
# [(273394, 'John Williams (4)'),
#  (407111, 'Kurt Weill'),
#  (194, 'Various Artists'),
#  (10263, 'David Bowie'),
#  (59756, 'Sarah Brightman'),
#  (39575, 'James Horner'),
#  (283111, 'Maurice Jarre'),
#  (15900, 'Ennio Morricone'),
#  (208267, 'Jerry Goldsmith'),
#  (59633, 'Andrew Poppy'),
#  (7779, 'Penguin Cafe Orchestra')]

# %%
# %%sql
# SELECT a1.artist_id, a1.name
# FROM artists a1
# WHERE EXISTS (
#     SELECT *
#     FROM artists a2
#     JOIN released_by USING(artist_id)
#     JOIN releases USING(release_id)
#     WHERE releases.genre = 'Pop'
#     AND a1.artist_id = a2.artist_id
# ) AND EXISTS (
#     SELECT *
#     FROM artists a2
#     JOIN released_by USING(artist_id)
#     JOIN releases USING(release_id)
#     WHERE releases.genre = 'Classical'
#     AND a1.artist_id = a2.artist_id
# )
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 11 rows affected.
# [(15900, 'Ennio Morricone'),
#  (283111, 'Maurice Jarre'),
#  (208267, 'Jerry Goldsmith'),
#  (10263, 'David Bowie'),
#  (194, 'Various Artists'),
#  (273394, 'John Williams (4)'),
#  (39575, 'James Horner'),
#  (59633, 'Andrew Poppy'),
#  (7779, 'Penguin Cafe Orchestra'),
#  (407111, 'Kurt Weill'),
#  (59756, 'Sarah Brightman')]

# %% [markdown]
# ## Exercise 3: Impact of release genre on average track duration and track count
# For this exercise, we want to find out how average track duration and track count varies across genres.
#
# To start, write a query which finds all of the distinct genres:

# %%
# %%sql
# SELECT DISTINCT genre
# FROM releases;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 15 rows affected.
# [('Folk, World, & Country',),
#  ('Reggae',),
#  ('Hip Hop',),
#  ('Blues',),
#  ('Stage & Screen',),
#  ('Latin',),
#  ('Non-Music',),
#  ('Electronic',),
#  ('Brass & Military',),
#  ('Classical',),
#  ('Pop',),
#  ('Rock',),
#  ('Funk / Soul',),
#  ('Jazz',),
#  ("Children's",)]

# %% [markdown]
# Take a guess as to which genre has:
# 1. The highest average track count?
# 2. The lowest average track count?
# 3. The longest average track duration?
# 4. The shortest average track duration?
#
# Next, write a query to calculate the average track count per genre:

# %%
# %%sql
# WITH tracks_per_release AS (
#     SELECT releases.genre, COUNT(*) AS track_count
#     FROM releases
#     JOIN tracks USING(release_id)
#     GROUP BY releases.release_id, releases.genre
# )
# SELECT tracks_per_release.genre, AVG(tracks_per_release.track_count) AS avg_track_count
# FROM tracks_per_release
# GROUP BY tracks_per_release.genre
# ORDER BY avg_track_count ASC;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 15 rows affected.
# [('Funk / Soul', Decimal('5.8397790055248619')),
#  ('Electronic', Decimal('6.0605250257308610')),
#  ('Pop', Decimal('7.5562060889929742')),
#  ('Hip Hop', Decimal('8.4942405038064490')),
#  ('Reggae', Decimal('8.9691318327974277')),
#  ('Rock', Decimal('9.3996764452113891')),
#  ('Classical', Decimal('9.5450980392156863')),
#  ('Brass & Military', Decimal('10.0000000000000000')),
#  ('Latin', Decimal('10.0771208226221080')),
#  ('Non-Music', Decimal('10.3572695035460993')),
#  ('Folk, World, & Country', Decimal('10.8524590163934426')),
#  ('Jazz', Decimal('11.0286427539088162')),
#  ("Children's", Decimal('11.8823529411764706')),
#  ('Stage & Screen', Decimal('14.5538461538461538')),
#  ('Blues', Decimal('14.5731707317073171'))]

# %% [markdown]
# Write a query to calculate the average duration per genre. Your result should have two attributes: `genre` and `avg_duration`.

# %%
# %%sql
# SELECT releases.genre, AVG(tracks.duration) AS avg_duration
# FROM releases JOIN tracks USING(release_id)
# GROUP BY releases.genre
# ORDER BY avg_duration ASC;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 15 rows affected.
# [('Stage & Screen', Decimal('232.7167019027484144')),
#  ('Blues', Decimal('241.7623430962343096')),
#  ('Pop', Decimal('250.8255075158840849')),
#  ('Rock', Decimal('264.4566639664592938')),
#  ('Brass & Military', Decimal('266.6083333333333333')),
#  ('Latin', Decimal('271.9007653061224490')),
#  ('Hip Hop', Decimal('276.7896082810916326')),
#  ('Reggae', Decimal('286.1795368179536818')),
#  ("Children's", Decimal('290.4801980198019802')),
#  ('Funk / Soul', Decimal('292.1099810785241249')),
#  ('Folk, World, & Country', Decimal('293.7428247734138973')),
#  ('Jazz', Decimal('301.5316479824634556')),
#  ('Electronic', Decimal('340.6974249708554896')),
#  ('Non-Music', Decimal('347.9161174355901738')),
#  ('Classical', Decimal('368.9800739523418242'))]

# %% [markdown]
# Did the results match what you expected? Copy your query into the following python script to plot the result.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Store the result of the query in a Python object (add your query here!)
result = %sql   SELECT releases.genre, AVG(tracks.duration) AS avg_duration \
                FROM releases JOIN tracks USING(release_id) \
                GROUP BY releases.genre \
                ORDER BY avg_duration ASC; \

# Convert the result to a Pandas data frame
df = result.DataFrame()

# Extract x and y values for a plot
x = df['genre'].tolist()
y = df['avg_duration'].tolist()

# Print them just for debugging
print(x)
print(y)

# Plot the distribution of scores
fig = plt.figure(figsize =(14, 7))
plt.barh(x, y, align='center')
plt.xlabel('Average Duration (s)')
plt.ylabel('Genre')
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 15 rows affected.
# ['Stage & Screen', 'Blues', 'Pop', 'Rock', 'Brass & Military', 'Latin', 'Hip Hop', 'Reggae', "Children's", 'Funk / Soul', 'Folk, World, & Country', 'Jazz', 'Electronic', 'Non-Music', 'Classical']
# [Decimal('232.7167019027484144'), Decimal('241.7623430962343096'), Decimal('250.8255075158840849'), Decimal('264.4566639664592938'), Decimal('266.6083333333333333'), Decimal('271.9007653061224490'), Decimal('276.7896082810916326'), Decimal('286.1795368179536818'), Decimal('290.4801980198019802'), Decimal('292.1099810785241249'), Decimal('293.7428247734138973'), Decimal('301.5316479824634556'), Decimal('340.6974249708554896'), Decimal('347.9161174355901738'), Decimal('368.9800739523418242')]
# Text(0, 0.5, 'Genre')

# %% [markdown]
# ## Exercise 4: Discuss query patterns and language features of SQL
# 1. What patterns did you use in many of the queries above?
#
# 2. Do you remember the theory behind them?
#
# 3. What makes SQL a declarative language and what advantages does that have?
#
# 4. What makes SQL a functional language and what advantages does that have?

# %% [markdown]
# ### Exercise 4: Solution
# 1. Most queries consist of the following basic operations. They will reoccur throughout the whole semester. Watch out for them!
#   * **Select**: select a subset of the rows/data records/items.
#   * **Project**: select a subset of the properties/ attributes/columns.
#   * **Join**: bring two datasets together based on a common attribute.
#   * **Group**: divide the items/ rows/records into groups and summarize each group with a single value.
#   * **Order**: order the items according to some criteria.
#
# 2. Relational algebra operators formalize most of this (grouping is technically not part of the algebra).
#
# 3. We only describe *what* we want, not how this should be computed. We *declare* what our intent is. This shifts the implementation effort from the programmer to the database system. The hope is that the system has more information at hand, such as data size, data distribution, information about the hardware, in order to choose the best way to compute the result. This results into efficient computation with little effort from the programmer.
#
# 4. SQL is functional because results of a query can be used as input of another query, either in form of tables or in form of scalars. This makes SQL expressive.

# %% [markdown]
# ## Exercise 5: Limits of SQL (optional)
# Explain what the following query does:

# %%
# %%sql
# WITH RECURSIVE
#     X AS (SELECT 3 AS Value),
#     artist_releases AS (
#         SELECT artists.artist_id, artists.name, releases.release_id, releases.title
#         FROM artists, released_by, releases
#         WHERE artists.artist_id = released_by.artist_id
#         AND released_by.release_id = releases.release_id
#     ),
#     collaborations AS (
#         SELECT DISTINCT ar1.artist_id AS left_id, ar1.name AS left_name,
#                 ar2.artist_id AS right_id, ar2.name AS right_name, 1 AS distance
#         FROM artist_releases AS ar1, artist_releases AS ar2
#         WHERE ar1.release_id = ar2.release_id
#         AND ar1.artist_id != ar2.artist_id
#     ),
#     X_hop_collaborations AS (
#         SELECT * FROM collaborations  -- base case
#         UNION
#         SELECT c1.left_id, c1.left_name, c2.right_id, c2.right_name, c1.distance + 1 AS distance
#         FROM X_hop_collaborations AS c1
#         JOIN collaborations c2 ON c1.right_id = c2.left_id
#         WHERE c1.distance < (SELECT * FROM X)
#     )
# SELECT *
# FROM X_hop_collaborations
# WHERE left_name = 'Radiohead'
# ORDER BY distance, right_name;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 511 rows affected.
# [(3840, 'Radiohead', 13785, 'Dino Lenny', 1),
#  (3840, 'Radiohead', 4478, 'DJ Shadow', 1),
#  (3840, 'Radiohead', 123982, 'Greenhouse Effect', 1),
#  (3840, 'Radiohead', 8760, 'Madonna', 1),
#  (3840, 'Radiohead', 3909, 'New Order', 1),
#  (3840, 'Radiohead', 337587, 'Panzah Zandahz', 1),
#  (3840, 'Radiohead', 19604, 'Phillip Boa & The Voodooclub', 1),
#  (3840, 'Radiohead', 232167, 'Wonky', 1),
#  (3840, 'Radiohead', 318, '808 State', 2),
#  (3840, 'Radiohead', 3352, 'Armand Van Helden', 2),
#  (3840, 'Radiohead', 4158, 'Arthur Baker', 2),
#  (3840, 'Radiohead', 7551, 'Blur', 2),
#  (3840, 'Radiohead', 21032, 'Boy George', 2),
#  (3840, 'Radiohead', 15687, 'Britney Spears', 2),
#  (3840, 'Radiohead', 11419, 'Bronski Beat', 2),
#  (3840, 'Radiohead', 19098, 'Cage', 2),
#  (3840, 'Radiohead', 16622, 'C + C Music Factory', 2),
#  (3840, 'Radiohead', 21723, 'Charlie Dark', 2),
#  (3840, 'Radiohead', 8485, 'Chicken Lips', 2),
#  (3840, 'Radiohead', 1196, 'CJ Bolland', 2),
#  (3840, 'Radiohead', 5455, 'Cut Chemist', 2),
#  (3840, 'Radiohead', 1289, 'Daft Punk', 2),
#  (3840, 'Radiohead', 2725, 'Depeche Mode', 2),
#  (3840, 'Radiohead', 8585, 'Divine Styler', 2),
#  (3840, 'Radiohead', 1718, 'DJ Die', 2),
#  (3840, 'Radiohead', 996, 'DJ Krush', 2),
#  (3840, 'Radiohead', 53529, 'D-Styles', 2),
#  (3840, 'Radiohead', 45115, 'Echo & The Bunnymen', 2),
#  (3840, 'Radiohead', 102093, 'Erdbeerlimes', 2),
#  (3840, 'Radiohead', 47297, 'Expansion Union', 2),
#  (3840, 'Radiohead', 7243, 'Gat Decor', 2),
#  (3840, 'Radiohead', 131497, 'Gene Loves Jezebel', 2),
#  (3840, 'Radiohead', 219, 'Green Velvet', 2),
#  (3840, 'Radiohead', 8029, 'Jamiroquai', 2),
#  (3840, 'Radiohead', 298134, 'Keak Da Sneak', 2),
#  (3840, 'Radiohead', 234647, 'Keane', 2),
#  (3840, 'Radiohead', 4128, 'Kosheen', 2),
#  (3840, 'Radiohead', 4654, 'Kraftwerk', 2),
#  (3840, 'Radiohead', 76720, 'Kristine Blond', 2),
#  (3840, 'Radiohead', 13608, 'Kylie Minogue', 2),
#  (3840, 'Radiohead', 50003, 'Lee-Cabrera', 2),
#  (3840, 'Radiohead', 136526, 'Lifers Group', 2),
#  (3840, 'Radiohead', 261760, 'Lynyrd Skynyrd', 2),
#  (3840, 'Radiohead', 15885, 'Michael Jackson', 2),
#  (3840, 'Radiohead', 17015, 'Midnight Star', 2),
#  (3840, 'Radiohead', 16153, 'Mirwais', 2),
#  (3840, 'Radiohead', 26918, 'Missy Elliott', 2),
#  (3840, 'Radiohead', 9383, 'Modjo', 2),
#  (3840, 'Radiohead', 164165, 'Otto Von Wernherr', 2),
#  (3840, 'Radiohead', 67218, 'Paul Oakenfold', 2),
#  (3840, 'Radiohead', 213833, 'Pedro Da Silva', 2),
#  (3840, 'Radiohead', 278, 'Peshay', 2),
#  (3840, 'Radiohead', 25670, "Quannum MC's", 2),
#  (3840, 'Radiohead', 960, 'Rabbit In The Moon', 2),
#  (3840, 'Radiohead', 3840, 'Radiohead', 2),
#  (3840, 'Radiohead', 350834, 'Roberto Vecchioni', 2),
#  (3840, 'Radiohead', 6438, 'Rob Searle', 2),
#  (3840, 'Radiohead', 25495, 'RZA', 2),
#  (3840, 'Radiohead', 67070, 'Sinitta', 2),
#  (3840, 'Radiohead', 1015, 'Slam', 2),
#  (3840, 'Radiohead', 25775, 'Souls Of Mischief', 2),
#  (3840, 'Radiohead', 68091, 'Sourmash', 2),
#  (3840, 'Radiohead', 14747, 'Sunz Of Man', 2),
#  (3840, 'Radiohead', 29890, 'The Clash', 2),
#  (3840, 'Radiohead', 459881, 'The Hitmixers', 2),
#  (3840, 'Radiohead', 245780, 'The Housemartins', 2),
#  (3840, 'Radiohead', 66852, 'The Prodigy', 2),
#  (3840, 'Radiohead', 116345, 'The White Stripes', 2),
#  (3840, 'Radiohead', 261590, 'Turf Talk', 2),
#  (3840, 'Radiohead', 6520, 'U2', 2),
#  (3840, 'Radiohead', 1280, 'Underworld', 2),
#  (3840, 'Radiohead', 87643, 'Violent Femmes', 2),
#  (3840, 'Radiohead', 57508, '2Mex', 3),
#  (3840, 'Radiohead', 64706, '3T', 3),
#  (3840, 'Radiohead', 101746, '4th Disciple', 3),
#  (3840, 'Radiohead', 51267, '702', 3),
#  (3840, 'Radiohead', 47327, 'AB/DC', 3),
#  (3840, 'Radiohead', 49145, 'ACO', 3),
#  (3840, 'Radiohead', 4505, 'Adam Freeland', 3),
#  (3840, 'Radiohead', 32010, 'Adele Bertei', 3),
#  (3840, 'Radiohead', 28104, 'Aesop Rock', 3),
#  (3840, 'Radiohead', 2532, 'Afrika Bambaataa & Soulsonic Force', 3),
#  (3840, 'Radiohead', 6921, 'Age Of Love', 3),
#  (3840, 'Radiohead', 137902, 'Alex Cartañá', 3),
#  (3840, 'Radiohead', 4690, 'Alison Limerick', 3),
#  (3840, 'Radiohead', 40729, 'Allister Whitehead', 3),
#  (3840, 'Radiohead', 82128, 'Al Mackenzie', 3),
#  (3840, 'Radiohead', 12846, 'Altern 8', 3),
#  (3840, 'Radiohead', 306473, 'AMC (3)', 3),
#  (3840, 'Radiohead', 30413, 'Andy Gray', 3),
#  (3840, 'Radiohead', 112754, 'Angie Martinez', 3),
#  (3840, 'Radiohead', 29376, 'Ann Saunderson', 3),
#  (3840, 'Radiohead', 185134, 'Antony And The Johnsons', 3),
#  (3840, 'Radiohead', 1609, 'Aphrohead', 3),
#  (3840, 'Radiohead', 325, 'A-Sides', 3),
#  (3840, 'Radiohead', 1627, 'AWeX', 3),
#  (3840, 'Radiohead', 37729, 'B.B. King', 3),
#  (3840, 'Radiohead', 309524, 'BCML', 3),
#  (3840, 'Radiohead', 10783, 'Beastie Boys', 3),
#  (3840, 'Radiohead', 6379, 'Bel Amour', 3),
#  (3840, 'Radiohead', 93375, 'Benny Benassi', 3),
#  (3840, 'Radiohead', 151144, 'Big Audio Dynamite II', 3),
#  (3840, 'Radiohead', 26245, 'Big Kap', 3),
#  (3840, 'Radiohead', 9704, 'Billie Ray Martin', 3),
#  (3840, 'Radiohead', 3279, 'Bill Riley', 3),
#  (3840, 'Radiohead', 54574, 'Bizzy B', 3),
#  (3840, 'Radiohead', 377731, 'BJ (4)', 3),
#  (3840, 'Radiohead', 1373, 'Björk', 3),
#  (3840, 'Radiohead', 16655, 'Blondie', 3),
#  (3840, 'Radiohead', 79241, 'Blow Out Express', 3),
#  (3840, 'Radiohead', 92900, 'Blu Cantrell', 3),
#  (3840, 'Radiohead', 7551, 'Blur', 3),
#  (3840, 'Radiohead', 390896, 'Bobby Digital', 3),
#  (3840, 'Radiohead', 80446, 'Bombdogs (2)', 3),
#  (3840, 'Radiohead', 235979, 'Boney M.', 3),
#  (3840, 'Radiohead', 39677, 'Bono', 3),
#  (3840, 'Radiohead', 21704, 'Boogie Boys', 3),
#  (3840, 'Radiohead', 22137, 'B.O.P.', 3),
#  (3840, 'Radiohead', 31751, 'Brandy (2)', 3),
#  (3840, 'Radiohead', 34001, 'Break', 3),
#  (3840, 'Radiohead', 5339, 'Breakbeat Era', 3),
#  (3840, 'Radiohead', 462261, 'Brittany Murphy', 3),
#  (3840, 'Radiohead', 4483, 'Brother Brown', 3),
#  (3840, 'Radiohead', 37906, 'Busta Rhymes', 3),
#  (3840, 'Radiohead', 11004, 'Byron Stingily', 3),
#  (3840, 'Radiohead', 2120, 'Capone', 3),
#  (3840, 'Radiohead', 1268, 'Carl Cox', 3),
#  (3840, 'Radiohead', 36603, 'Carly Simon', 3),
#  (3840, 'Radiohead', 125912, 'Casual', 3),
#  (3840, 'Radiohead', 16622, 'C + C Music Factory', 3),
#  (3840, 'Radiohead', 3870, 'Cevin Fisher', 3),
#  (3840, 'Radiohead', 421022, 'Charly (3)', 3),
#  (3840, 'Radiohead', 8485, 'Chicken Lips', 3),
#  (3840, 'Radiohead', 199733, 'Christian Dio', 3),
#  (3840, 'Radiohead', 77855, 'Christina Aguilera', 3),
#  (3840, 'Radiohead', 232451, 'Ciara (2)', 3),
#  (3840, 'Radiohead', 1196, 'CJ Bolland', 3),
#  (3840, 'Radiohead', 147231, 'CM', 3),
#  (3840, 'Radiohead', 946, 'Coldcut', 3),
#  (3840, 'Radiohead', 34141, 'Colin Tevendale', 3),
#  (3840, 'Radiohead', 12604, 'Confucius', 3),
#  (3840, 'Radiohead', 48158, 'Co-Ordinate', 3),
#  (3840, 'Radiohead', 14168, 'Cosmos', 3),
#  (3840, 'Radiohead', 12626, 'Craig David', 3),
#  (3840, 'Radiohead', 92256, 'Craig Wedren', 3),
#  (3840, 'Radiohead', 9706, 'Culture Club', 3),
#  (3840, 'Radiohead', 26802, 'Cyberia', 3),
#  (3840, 'Radiohead', 36099, 'Da Brat', 3),
#  (3840, 'Radiohead', 64774, 'Daddy Kev', 3),
#  (3840, 'Radiohead', 1289, 'Daft Punk', 3),
#  (3840, 'Radiohead', 3482, 'Danny Krivit', 3),
#  (3840, 'Radiohead', 24023, 'Danny Rampling', 3),
#  (3840, 'Radiohead', 1644, 'Danny Tenaglia', 3),
#  (3840, 'Radiohead', 14148, 'Dark Globe', 3),
#  (3840, 'Radiohead', 18135, 'Darkleaf', 3),
#  (3840, 'Radiohead', 184375, 'Dave Charlesworth', 3),
#  (3840, 'Radiohead', 1000, 'Dave Clarke', 3),
#  (3840, 'Radiohead', 10263, 'David Bowie', 3),
#  (3840, 'Radiohead', 121721, 'Deborah Cooper', 3),
#  (3840, 'Radiohead', 7294, 'Degrees Of Motion', 3),
#  (3840, 'Radiohead', 31712, 'Del Tha Funkee Homosapien', 3),
#  (3840, 'Radiohead', 2725, 'Depeche Mode', 3),
#  (3840, 'Radiohead', 650, 'Derrick May', 3),
#  (3840, 'Radiohead', 47742, 'Diana Ross', 3),
#  (3840, 'Radiohead', 315, 'Dillinja', 3),
#  (3840, 'Radiohead', 13785, 'Dino Lenny', 3),
#  (3840, 'Radiohead', 230640, 'Dirtsman', 3),
#  (3840, 'Radiohead', 8585, 'Divine Styler', 3),
#  (3840, 'Radiohead', 1718, 'DJ Die', 3),
#  (3840, 'Radiohead', 17398, 'DJ Eric', 3),
#  (3840, 'Radiohead', 212243, 'DJ Esp (2)', 3),
#  (3840, 'Radiohead', 31820, 'DJ Face', 3),
#  (3840, 'Radiohead', 1431, 'DJ Food', 3),
#  (3840, 'Radiohead', 5172, 'DJ Misjah', 3),
#  (3840, 'Radiohead', 19857, 'DJ Monk', 3),
#  (3840, 'Radiohead', 583263, 'DJ Neesty', 3),
#  (3840, 'Radiohead', 37863, 'DJ Nu-Mark', 3),
#  (3840, 'Radiohead', 2053, 'DJ Pierre', 3),
#  (3840, 'Radiohead', 4478, 'DJ Shadow', 3),
#  (3840, 'Radiohead', 170, 'DJ Sneak', 3),
#  (3840, 'Radiohead', 6270, 'Donna Summer', 3),
#  (3840, 'Radiohead', 16500, 'Dot Allison', 3),
#  (3840, 'Radiohead', 465585, 'Dr. Martin Luther King, Jr.', 3),
#  (3840, 'Radiohead', 12176, 'Dr. S. Gachet', 3),
#  (3840, 'Radiohead', 114239, 'Drums Power', 3),
#  (3840, 'Radiohead', 4245, 'Duane Harden', 3),
#  (3840, 'Radiohead', 238558, 'Dubversive', 3),
#  (3840, 'Radiohead', 9591, 'Duke', 3),
#  (3840, 'Radiohead', 6521, 'Dylan Rhymes', 3),
#  (3840, 'Radiohead', 31444, 'Dynamite MC', 3),
#  (3840, 'Radiohead', 79103, 'Dynasty', 3),
#  (3840, 'Radiohead', 16748, 'Eartha Kitt', 3),
#  (3840, 'Radiohead', 22164, 'Earth, Wind & Fire', 3),
#  (3840, 'Radiohead', 45115, 'Echo & The Bunnymen', 3),
#  (3840, 'Radiohead', 80059, 'Ecstacy', 3),
#  (3840, 'Radiohead', 16505, 'Eddie Lock', 3),
#  (3840, 'Radiohead', 264475, 'Edie Brickell & New Bohemians', 3),
#  (3840, 'Radiohead', 63774, 'Eightball & M.J.G.', 3),
#  (3840, 'Radiohead', 21881, 'Elektronauten', 3),
#  (3840, 'Radiohead', 2202, 'EL-P', 3),
#  (3840, 'Radiohead', 38661, 'Eminem', 3),
#  (3840, 'Radiohead', 9807, 'Enya', 3),
#  (3840, 'Radiohead', 4033, 'Eric B. & Rakim', 3),
#  (3840, 'Radiohead', 12185, 'Esthero', 3),
#  (3840, 'Radiohead', 13911, 'Eurythmics', 3),
#  (3840, 'Radiohead', 163505, 'Evanescence', 3),
#  (3840, 'Radiohead', 300688, 'Exhibit A (2)', 3),
#  (3840, 'Radiohead', 187475, 'Extra Prolific', 3),
#  (3840, 'Radiohead', 2705, 'Fad Gadget', 3),
#  (3840, 'Radiohead', 4118, 'Faithless', 3),
#  (3840, 'Radiohead', 26912, 'Falco', 3),
#  (3840, 'Radiohead', 3101, 'Fatboy Slim', 3),
#  (3840, 'Radiohead', 66152, 'Fatman Scoop', 3),
#  (3840, 'Radiohead', 1669, 'Felix', 3),
#  (3840, 'Radiohead', 1570, 'Felix Da Housecat', 3),
#  (3840, 'Radiohead', 9086, 'Fischerspooner', 3),
#  (3840, 'Radiohead', 47333, 'Fleetwood Mac', 3),
#  (3840, 'Radiohead', 1859, 'Flytronix', 3),
#  (3840, 'Radiohead', 6273, 'Frankie Goes To Hollywood', 3),
#  (3840, 'Radiohead', 52833, 'Frank Sinatra', 3),
#  (3840, 'Radiohead', 223808, 'Free (2)', 3),
#  (3840, 'Radiohead', 57393, 'Freedom Williams', 3),
#  (3840, 'Radiohead', 4655, 'Front 242', 3),
#  (3840, 'Radiohead', 17843, 'Frontside', 3),
#  (3840, 'Radiohead', 27103, 'Gabriel & Dresden', 3),
#  (3840, 'Radiohead', 50570, 'Gaznevada', 3),
#  (3840, 'Radiohead', 131497, 'Gene Loves Jezebel', 3),
#  (3840, 'Radiohead', 44958, 'Ghostface Killah', 3),
#  (3840, 'Radiohead', 96151, 'Gina Thompson', 3),
#  (3840, 'Radiohead', 2825, 'Goldie', 3),
#  (3840, 'Radiohead', 408490, 'Go Like This', 3),
#  (3840, 'Radiohead', 6378, 'Gorillaz', 3),
#  (3840, 'Radiohead', 14639, 'Gravity', 3),
#  (3840, 'Radiohead', 780604, 'Greek Salad', 3),
#  (3840, 'Radiohead', 123982, 'Greenhouse Effect', 3),
#  (3840, 'Radiohead', 219, 'Green Velvet', 3),
#  (3840, 'Radiohead', 23603, 'Hardcorey', 3),
#  (3840, 'Radiohead', 179014, 'Hell Razah', 3),
#  (3840, 'Radiohead', 11786, 'Hi-Gate', 3),
#  (3840, 'Radiohead', 715831, 'High Aspirations (2)', 3),
#  (3840, 'Radiohead', 116253, 'Hot Hot Heat', 3),
#  (3840, 'Radiohead', 58654, 'Hoxton Whores', 3),
#  (3840, 'Radiohead', 1612, 'Humate', 3),
#  (3840, 'Radiohead', 1029, 'I:Cube', 3),
#  (3840, 'Radiohead', 2994, 'Ignacio', 3),
#  (3840, 'Radiohead', 35086, 'Inaya Day', 3),
#  (3840, 'Radiohead', 23259, 'Indeep', 3),
#  (3840, 'Radiohead', 21209, 'James Lavelle', 3),
#  (3840, 'Radiohead', 115944, 'James Reese', 3),
#  (3840, 'Radiohead', 8029, 'Jamiroquai', 3),
#  (3840, 'Radiohead', 8024, 'Janet Jackson', 3),
#  (3840, 'Radiohead', 30313, 'Jason Donovan', 3),
#  (3840, 'Radiohead', 5843, 'Jason Jinx', 3),
#  (3840, 'Radiohead', 892, 'Jaydee', 3),
#  (3840, 'Radiohead', 21742, 'Jay-Z', 3),
#  (3840, 'Radiohead', 11051, 'JDS', 3),
#  (3840, 'Radiohead', 267, 'Jega', 3),
#  (3840, 'Radiohead', 51984, 'Jennifer Lopez', 3),
#  (3840, 'Radiohead', 7300, 'Jesus Loves You', 3),
#  (3840, 'Radiohead', 28365, 'Jimmy Somerville', 3),
#  (3840, 'Radiohead', 137105, 'JJ Flores & Steve Smooth', 3),
#  (3840, 'Radiohead', 296, 'J Majik', 3),
#  (3840, 'Radiohead', 11829, 'John Creamer & Stephane K', 3),
#  (3840, 'Radiohead', 13965, 'Johnny Vicious', 3),
#  (3840, 'Radiohead', 4825, 'Jon Carter', 3),
#  (3840, 'Radiohead', 32212, 'Jon Hassell', 3),
#  (3840, 'Radiohead', 739, 'Jori Hulkkonen', 3),
#  (3840, 'Radiohead', 125155, 'Josh Patrick', 3),
#  (3840, 'Radiohead', 22720, 'Jovanotti', 3),
#  (3840, 'Radiohead', 5762, 'Judge Jules', 3),
#  (3840, 'Radiohead', 356722, 'June Miles-Kingston', 3),
#  (3840, 'Radiohead', 65484, 'Jungle Juice', 3),
#  (3840, 'Radiohead', 1647, 'Junior Sanchez', 3),
#  (3840, 'Radiohead', 602401, 'Kamanchi', 3),
#  (3840, 'Radiohead', 7165, 'Kariya', 3),
#  (3840, 'Radiohead', 235133, 'Kasabian', 3),
#  (3840, 'Radiohead', 5825, 'Kathy Brown', 3),
#  (3840, 'Radiohead', 298134, 'Keak Da Sneak', 3),
#  (3840, 'Radiohead', 234647, 'Keane', 3),
#  (3840, 'Radiohead', 101777, 'Keith Washington', 3),
#  (3840, 'Radiohead', 8285, 'Kelis', 3),
#  (3840, 'Radiohead', 309547, 'Kid Vicious (2)', 3),
#  (3840, 'Radiohead', 13408, 'Killing Joke', 3),
#  (3840, 'Radiohead', 1749, 'King Britt', 3),
#  (3840, 'Radiohead', 4654, 'Kraftwerk', 3),
#  (3840, 'Radiohead', 192387, 'Krush Groove Productions', 3),
#  (3840, 'Radiohead', 24422, 'Krust', 3),
#  (3840, 'Radiohead', 13608, 'Kylie Minogue', 3),
#  (3840, 'Radiohead', 30918, 'Kym Mazelle', 3),
#  (3840, 'Radiohead', 75985, 'Lakeside', 3),
#  (3840, 'Radiohead', 6136, 'Latyrx', 3),
#  (3840, 'Radiohead', 90, 'Layo & Bushwacka!', 3),
#  (3840, 'Radiohead', 34278, 'Led Zeppelin', 3),
#  (3840, 'Radiohead', 1844430, 'Leiji Matsumoto', 3),
#  (3840, 'Radiohead', 63332, 'Lenny Kravitz', 3),
#  (3840, 'Radiohead', 114823, "Lil' Kim", 3),
#  (3840, 'Radiohead', 789, "Lil' Louis", 3),
#  (3840, 'Radiohead', 239305, "Lil' Scrappy", 3),
#  (3840, 'Radiohead', 110359, 'Lisa "Left Eye" Lopes', 3),
#  (3840, 'Radiohead', 60901, 'LMC', 3),
#  (3840, 'Radiohead', 56848, 'Lost Vegas', 3),
#  (3840, 'Radiohead', 321, 'LTJ Bukem', 3),
#  (3840, 'Radiohead', 36100, 'Ludacris', 3),
#  (3840, 'Radiohead', 120009, 'Lumidee', 3),
#  (3840, 'Radiohead', 6142, 'Lyrics Born', 3),
#  (3840, 'Radiohead', 16508, 'Madlib', 3),
#  (3840, 'Radiohead', 8760, 'Madonna', 3),
#  (3840, 'Radiohead', 177491, 'Magoo (3)', 3),
#  (3840, 'Radiohead', 67532, 'M.A.N.D.Y.', 3),
#  (3840, 'Radiohead', 32915, 'Marc Almond', 3),
#  (3840, 'Radiohead', 31077, 'Mark Moore', 3),
#  (3840, 'Radiohead', 12590, 'M|A|R|R|S', 3),
#  (3840, 'Radiohead', 6540, 'Martin Solveig', 3),
#  (3840, 'Radiohead', 4778, 'Mary J. Blige', 3),
#  (3840, 'Radiohead', 17291, 'M-Beat', 3),
#  (3840, 'Radiohead', 16412, 'MC Solaar', 3),
#  (3840, 'Radiohead', 22980, 'MC Tunes', 3),
#  (3840, 'Radiohead', 3172, 'Meat Katie', 3),
#  (3840, 'Radiohead', 52938, 'Melanie B', 3),
#  (3840, 'Radiohead', 126064, 'Memphis Bleek', 3),
#  (3840, 'Radiohead', 25058, 'MF Doom', 3),
#  (3840, 'Radiohead', 15885, 'Michael Jackson', 3),
#  (3840, 'Radiohead', 37797, 'Michael Kilkie', 3),
#  (3840, 'Radiohead', 34, 'Miguel Migs', 3),
#  (3840, 'Radiohead', 57843, 'Mim', 3),
#  (3840, 'Radiohead', 4246, 'Mita', 3),
#  (3840, 'Radiohead', 86604, 'Mixologists', 3),
#  (3840, 'Radiohead', 41238, 'M+K', 3),
#  (3840, 'Radiohead', 1031, 'Moby', 3),
#  (3840, 'Radiohead', 94999, 'Mocha', 3),
#  (3840, 'Radiohead', 326109, 'Mr. Collipark', 3),
#  (3840, 'Radiohead', 2446, 'Mr. Fingers', 3),
#  (3840, 'Radiohead', 18140, 'Mumbles', 3),
#  (3840, 'Radiohead', 90417, 'Musique (2)', 3),
#  (3840, 'Radiohead', 9708, "N'Dea Davenport", 3),
#  (3840, 'Radiohead', 42713, 'Neil Mac', 3),
#  (3840, 'Radiohead', 145843, 'N*E*R*D', 3),
#  (3840, 'Radiohead', 3909, 'New Order', 3),
#  (3840, 'Radiohead', 36665, 'Nick Cave & The Bad Seeds', 3),
#  (3840, 'Radiohead', 57821, 'Nick Corline', 3),
#  (3840, 'Radiohead', 5887, 'Nick Warren', 3),
#  (3840, 'Radiohead', 208484, 'Nicole Wray', 3),
#  (3840, 'Radiohead', 131987, 'Nightlife Unlimited', 3),
#  (3840, 'Radiohead', 116412, 'Nikeeta', 3),
#  (3840, 'Radiohead', 125246, 'Nirvana', 3),
#  (3840, 'Radiohead', 2709, 'Nitzer Ebb', 3),
#  (3840, 'Radiohead', 18128, 'Nobody', 3),
#  (3840, 'Radiohead', 58863, 'NRC', 3),
#  (3840, 'Radiohead', 69433, '*NSYNC', 3),
#  (3840, 'Radiohead', 142885, 'Old School Junkies', 3),
#  (3840, 'Radiohead', 6519, 'One Dove', 3),
#  (3840, 'Radiohead', 235377, 'Optimus (2)', 3),
#  (3840, 'Radiohead', 34170, 'Organisation', 3),
#  (3840, 'Radiohead', 337587, 'Panzah Zandahz', 3),
#  (3840, 'Radiohead', 1706, 'Paperclip People', 3),
#  (3840, 'Radiohead', 35301, 'Paul McCartney', 3),
#  (3840, 'Radiohead', 67218, 'Paul Oakenfold', 3),
#  (3840, 'Radiohead', 1049, 'Paul van Dyk', 3),
#  (3840, 'Radiohead', 213833, 'Pedro Da Silva', 3),
#  (3840, 'Radiohead', 278, 'Peshay', 3),
#  (3840, 'Radiohead', 12285, 'Pete Tong', 3),
#  (3840, 'Radiohead', 156533, 'Phase 2 (3)', 3),
#  (3840, 'Radiohead', 58367, 'Phil Daniels', 3),
#  (3840, 'Radiohead', 19604, 'Phillip Boa & The Voodooclub', 3),
#  (3840, 'Radiohead', 2269, 'Phoenix', 3),
#  (3840, 'Radiohead', 417, 'Photek', 3),
#  (3840, 'Radiohead', 49436, 'Pink Flood', 3),
#  (3840, 'Radiohead', 45467, 'Pink Floyd', 3),
#  (3840, 'Radiohead', 13606, 'P.M. Dawn', 3),
#  (3840, 'Radiohead', 86163, 'Pointer Sisters', 3),
#  (3840, 'Radiohead', 28795, 'Prince', 3),
#  (3840, 'Radiohead', 13999, 'Propaganda', 3),
#  (3840, 'Radiohead', 5305, 'Psilocybin', 3),
#  (3840, 'Radiohead', 35848, 'Q-Tip', 3),
#  (3840, 'Radiohead', 37601, 'Quadrant Six', 3),
#  (3840, 'Radiohead', 25670, "Quannum MC's", 3),
#  (3840, 'Radiohead', 17546, 'Quincy Jones', 3),
#  (3840, 'Radiohead', 4230, 'Quivver', 3),
#  (3840, 'Radiohead', 68464, 'Q-Unique', 3),
#  (3840, 'Radiohead', 2332, 'Ray Keith', 3),
#  (3840, 'Radiohead', 168692, 'Real Live', 3),
#  (3840, 'Radiohead', 67708, 'Redanka', 3),
#  (3840, 'Radiohead', 1018, 'Rejuvination', 3),
#  (3840, 'Radiohead', 54423, 'Reverend Jerri Curl', 3),
#  (3840, 'Radiohead', 128019, 'R.M.D.', 3),
#  (3840, 'Radiohead', 17212, 'Robbie Williams', 3),
#  (3840, 'Radiohead', 7292, 'Robert Miles', 3),
#  (3840, 'Radiohead', 66727, 'Robin S.', 3),
#  (3840, 'Radiohead', 16747, 'Rockers Revenge', 3),
#  (3840, 'Radiohead', 14954, 'Rodney P', 3),
#  (3840, 'Radiohead', 27415, 'Roger Johnson', 3),
#  (3840, 'Radiohead', 4719, 'Roger Sanchez', 3),
#  (3840, 'Radiohead', 10780, 'Roland Clark', 3),
#  (3840, 'Radiohead', 338, 'Roni Size', 3),
#  (3840, 'Radiohead', 7449, 'Ronny Jordan', 3),
#  (3840, 'Radiohead', 56621, 'Roxy Music', 3),
#  (3840, 'Radiohead', 40792, 'Royce Da 5\'9"', 3),
#  (3840, 'Radiohead', 219213, 'Run-DMC', 3),
#  (3840, 'Radiohead', 16421, 'RYU', 3),
#  (3840, 'Radiohead', 25495, 'RZA', 3),
#  (3840, 'Radiohead', 114565, 'Sahara (2)', 3),
#  (3840, 'Radiohead', 7981, 'Sash!', 3),
#  (3840, 'Radiohead', 3365, 'Sasha', 3),
#  (3840, 'Radiohead', 7606, 'Scott Grooves', 3),
#  (3840, 'Radiohead', 111502, 'Sean Paul', 3),
#  (3840, 'Radiohead', 458982, 'Serge Santiágo', 3),
#  (3840, 'Radiohead', 171524, 'SFB', 3),
#  (3840, 'Radiohead', 17960, 'Shalamar', 3),
#  (3840, 'Radiohead', 167887, 'Shapeshifters', 3),
#  (3840, 'Radiohead', 126431, 'Shirley Brown', 3),
#  (3840, 'Radiohead', 34225, 'Shortkut', 3),
#  (3840, 'Radiohead', 1685, 'Sister Bliss', 3),
#  (3840, 'Radiohead', 11217, 'Size 9', 3),
#  (3840, 'Radiohead', 25649, 'Skitz', 3),
#  (3840, 'Radiohead', 131124, 'Skulduggery', 3),
#  (3840, 'Radiohead', 5487, 'Slide', 3),
#  (3840, 'Radiohead', 14179, 'Slipmaster J', 3),
#  (3840, 'Radiohead', 459092, 'Slumberland', 3),
#  (3840, 'Radiohead', 10586, 'Slum Village', 3),
#  (3840, 'Radiohead', 287920, 'Soba Nobodies', 3),
#  (3840, 'Radiohead', 25775, 'Souls Of Mischief', 3),
#  (3840, 'Radiohead', 441702, 'Soul Stew', 3),
#  (3840, 'Radiohead', 30884, 'Sound Factory', 3),
#  (3840, 'Radiohead', 13335, 'Sound Of The Future', 3),
#  (3840, 'Radiohead', 144984, 'Spalding Rockwell', 3),
#  (3840, 'Radiohead', 652, 'Special Forces', 3),
#  (3840, 'Radiohead', 15816, 'Spice', 3),
#  (3840, 'Radiohead', 29815, 'Steve Miller Band', 3),
#  (3840, 'Radiohead', 83506, 'Steven McCreery', 3),
#  (3840, 'Radiohead', 18956, 'Stevie Wonder', 3),
#  (3840, 'Radiohead', 215505, 'Studio B', 3),
#  (3840, 'Radiohead', 26531, 'Sub Sub', 3),
#  (3840, 'Radiohead', 53768, 'Suga Bang Bang', 3),
#  (3840, 'Radiohead', 217253, 'Summerheadz', 3),
#  (3840, 'Radiohead', 14747, 'Sunz Of Man', 3),
#  (3840, 'Radiohead', 23443, 'Supercar', 3),
#  (3840, 'Radiohead', 158787, 'Super Cat (2)', 3),
#  (3840, 'Radiohead', 907144, 'Surge (5)', 3),
#  (3840, 'Radiohead', 38034, 'Suv', 3),
#  (3840, 'Radiohead', 1328, 'Sven Väth', 3),
#  (3840, 'Radiohead', 15082, 'Switchkraft', 3),
#  (3840, 'Radiohead', 242197, 'Takako Matsu', 3),
#  (3840, 'Radiohead', 32695, 'Tali', 3),
#  (3840, 'Radiohead', 22979, 'Teebee', 3),
#  (3840, 'Radiohead', 4244, 'Tekitha', 3),
#  (3840, 'Radiohead', 293637, 'The Artist (Formerly Known As Prince)', 3),
#  (3840, 'Radiohead', 7142, 'The Art Of Noise', 3),
#  (3840, 'Radiohead', 39727, 'The Brooklyn, Bronx & Queens Band', 3),
#  (3840, 'Radiohead', 64601, 'The Communards', 3),
#  (3840, 'Radiohead', 47325, 'The Crazies', 3),
#  (3840, 'Radiohead', 28972, 'The Cure', 3),
#  (3840, 'Radiohead', 78668, 'The Deele', 3),
#  (3840, 'Radiohead', 16625, 'The Fog', 3),
#  (3840, 'Radiohead', 82947, 'The Grouch', 3),
#  (3840, 'Radiohead', 122695, 'The Horse', 3),
#  (3840, 'Radiohead', 41157, 'The Jackson 5', 3),
#  (3840, 'Radiohead', 169154, 'The Jacksons', 3),
#  (3840, 'Radiohead', 10578, 'The Pharcyde', 3),
#  (3840, 'Radiohead', 8275, 'The Poets Of Rhythm', 3),
#  (3840, 'Radiohead', 7987, 'The Police', 3),
#  (3840, 'Radiohead', 25946, 'The Project (3)', 3),
#  (3840, 'Radiohead', 191080, 'The Scheme Team', 3),
#  (3840, 'Radiohead', 194057, 'The Socialites', 3),
#  (3840, 'Radiohead', 253929, 'The Sweet', 3),
#  (3840, 'Radiohead', 5362, 'The Todd Terry Project', 3),
#  (3840, 'Radiohead', 37745, 'The Truper', 3),
#  (3840, 'Radiohead', 51979, 'The Whispers', 3),
#  (3840, 'Radiohead', 377411, 'The Wiz Stars', 3),
#  (3840, 'Radiohead', 3775, 'Thomas Bangalter', 3),
#  (3840, 'Radiohead', 4488, 'Three Drives', 3),
#  (3840, 'Radiohead', 157843, 'Timbaland & Magoo', 3),
#  (3840, 'Radiohead', 171, 'Tim Deluxe', 3),
#  (3840, 'Radiohead', 16709, 'Tom Novy', 3),
#  (3840, 'Radiohead', 104440, 'Tony Arzadon', 3),
#  (3840, 'Radiohead', 62882, 'Tony King', 3),
#  (3840, 'Radiohead', 9902, 'Tori Amos', 3),
#  (3840, 'Radiohead', 143942, 'Toshinori Kondo', 3),
#  (3840, 'Radiohead', 10234, 'Towa Tei', 3),
#  (3840, 'Radiohead', 161091, 'Tracy Chapman', 3),
#  (3840, 'Radiohead', 5816, 'Trilogy', 3),
#  (3840, 'Radiohead', 75833, 'Tunde Ayanyemi', 3),
#  (3840, 'Radiohead', 261590, 'Turf Talk', 3),
#  (3840, 'Radiohead', 39454, 'Tweet', 3),
#  (3840, 'Radiohead', 97633, 'Twigy', 3),
#  (3840, 'Radiohead', 73435, 'Tyrone Palmer', 3),
#  (3840, 'Radiohead', 6520, 'U2', 3),
#  (3840, 'Radiohead', 21767, 'UB40', 3),
#  (3840, 'Radiohead', 1280, 'Underworld', 3),
#  (3840, 'Radiohead', 3194, 'UNKLE', 3),
#  (3840, 'Radiohead', 7027, 'Vangelis', 3),
#  (3840, 'Radiohead', 194, 'Various Artists', 3),
#  (3840, 'Radiohead', 36434, 'Vinyl Baby', 3),
#  (3840, 'Radiohead', 3479, 'Visage', 3),
#  (3840, 'Radiohead', 80351, 'Vision Masters', 3),
#  (3840, 'Radiohead', 119795, 'Viveen Wray', 3),
#  (3840, 'Radiohead', 862094, 'Wacko Bass', 3),
#  (3840, 'Radiohead', 9707, 'War', 3),
#  (3840, 'Radiohead', 3128, 'Way Out West', 3),
#  (3840, 'Radiohead', 24680, 'Who Da Funk', 3),
#  (3840, 'Radiohead', 232167, 'Wonky', 3),
#  (3840, 'Radiohead', 12157, "Workin' Happily", 3),
#  (3840, 'Radiohead', 1002011, 'Wu-Tang Killa Bees', 3),
#  (3840, 'Radiohead', 50200, 'Wyclef Jean', 3),
#  (3840, 'Radiohead', 2937, 'X-Press 2', 3),
#  (3840, 'Radiohead', 2713, 'Yazoo', 3),
#  (3840, 'Radiohead', 22061, 'Yellow Magic Orchestra', 3),
#  (3840, 'Radiohead', 165375, 'Ying Yang Twins', 3),
#  (3840, 'Radiohead', 5968, 'Yomanda', 3),
#  (3840, 'Radiohead', 439156, 'Zeefungk', 3),
#  (3840, 'Radiohead', 67592, 'Zelma Davis', 3),
#  (3840, 'Radiohead', 15915, 'Zimbabwe Legit', 3)]

# %% [markdown]
# ### Exercise 5: Solution
# The query interprets the database as an undirected graph where *Artists* are nodes and edges exist between artists that have released an album together (i.e., collaborated). It then returns all of the artists which are at most `X` hops from a given artist in the graph. Even if the problem is simple when phrased with graph terminology, we can see that the query itself is quite complex: evidently, **SQL is not built for graph analysis!**. In the later weeks of the course, we will see tools that make graph analysis much more intuitive.
#
# To understand why the query does what it does, think about how we can find all artists exactly `X` hops from a given artist. Firstly, we need to be able to easily retrieve all *directly* collaborating artists, i.e., the set of edges:

# %%
# %%sql
# WITH artist_releases AS (
#     SELECT artists.artist_id, artists.name, releases.release_id, releases.title
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN releases USING (release_id)
# )
# SELECT DISTINCT ar1.artist_id AS left_id, ar1.name AS left_name,
#         ar2.artist_id AS right_id, ar2.name AS right_name, 1 AS distance
# FROM artist_releases AS ar1, artist_releases AS ar2
# WHERE ar1.release_id = ar2.release_id
# AND ar1.artist_id != ar2.artist_id
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 10 rows affected.
# [(1, 'The Persuader', 89, 'Mr. James Barth', 1),
#  (1, 'The Persuader', 674, 'Stephan Grieder', 1),
#  (3, 'Josh Wink', 11, 'DJ Dozia', 1),
#  (3, 'Josh Wink', 789, "Lil' Louis", 1),
#  (3, 'Josh Wink', 1268, 'Carl Cox', 1),
#  (3, 'Josh Wink', 2893, 'Woody McBride', 1),
#  (3, 'Josh Wink', 4367, 'DJ ESP', 1),
#  (3, 'Josh Wink', 11217, 'Size 9', 1),
#  (3, 'Josh Wink', 15346, 'Vinylgroover & The Red Hed', 1),
#  (3, 'Josh Wink', 27460, 'The Interpreters', 1)]

# %% [markdown]
# where we first join artists with their releases under `artist_releases`, and then join `artist_releases` with itself to find all pairs of artists which have released the same `release_id`. We limit the query results to 10 for demonstration purposes.
#
# We give this query the alias `collaborations` and join it with itself on a mutual `artist_id` to find all collaborations with two hops:

# %%
# %%sql
# WITH artist_releases AS (
#     SELECT artists.artist_id, artists.name, releases.release_id, releases.title
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN releases USING (release_id)
# ),
# collaborations AS (
#     SELECT DISTINCT ar1.artist_id AS left_id, ar1.name AS left_name,
#             ar2.artist_id AS right_id, ar2.name AS right_name, 1 AS distance
#     FROM artist_releases AS ar1, artist_releases AS ar2
#     WHERE ar1.release_id = ar2.release_id
#     AND ar1.artist_id != ar2.artist_id
# ),
# two_hop_collaborations AS (
#     SELECT DISTINCT c1.left_id, c1.left_name, c2.right_id, c2.right_name
#     FROM collaborations c1, collaborations c2
#     WHERE c1.right_id = c2.left_id
# )
# SELECT *
# FROM two_hop_collaborations
# WHERE left_name = 'Radiohead'
# ORDER BY right_name
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 10 rows affected.
# [(3840, 'Radiohead', 318, '808 State'),
#  (3840, 'Radiohead', 3352, 'Armand Van Helden'),
#  (3840, 'Radiohead', 4158, 'Arthur Baker'),
#  (3840, 'Radiohead', 7551, 'Blur'),
#  (3840, 'Radiohead', 21032, 'Boy George'),
#  (3840, 'Radiohead', 15687, 'Britney Spears'),
#  (3840, 'Radiohead', 11419, 'Bronski Beat'),
#  (3840, 'Radiohead', 19098, 'Cage'),
#  (3840, 'Radiohead', 16622, 'C + C Music Factory'),
#  (3840, 'Radiohead', 21723, 'Charlie Dark')]

# %% [markdown]
# We can iteratively add indirections with another join like so:

# %%
# %%sql
# WITH artist_releases AS (
#     SELECT artists.artist_id, artists.name, releases.release_id, releases.title
#     FROM artists
#     JOIN released_by USING(artist_id)
#     JOIN releases USING (release_id)
# ),
# collaborations AS (
#     SELECT DISTINCT ar1.artist_id AS left_id, ar1.name AS left_name,
#             ar2.artist_id AS right_id, ar2.name AS right_name, 1 AS distance
#     FROM artist_releases AS ar1, artist_releases AS ar2
#     WHERE ar1.release_id = ar2.release_id
#     AND ar1.artist_id != ar2.artist_id
# ),
# two_hop_collaborations AS (
#     SELECT DISTINCT c1.left_id, c1.left_name, c2.right_id, c2.right_name
#     FROM collaborations c1, collaborations c2
#     WHERE c1.right_id = c2.left_id
# ),
# three_hop_collaborations AS (
#     SELECT DISTINCT c1.left_id, c1.left_name, c2.right_id, c2.right_name
#     FROM two_hop_collaborations c1, collaborations c2
#     WHERE c1.right_id = c2.left_id
# ),
# four_hop_collaborations AS (
#     SELECT DISTINCT c1.left_id, c1.left_name, c2.right_id, c2.right_name
#     FROM three_hop_collaborations c1, collaborations c2
#     WHERE c1.right_id = c2.left_id
# )
# SELECT *
# FROM four_hop_collaborations
# WHERE left_name = 'Radiohead'
# ORDER BY right_name
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 10 rows affected.
# [(3840, 'Radiohead', 113470, '112'),
#  (3840, 'Radiohead', 55439, '1 Giant Leap'),
#  (3840, 'Radiohead', 36856, '20 Fingers'),
#  (3840, 'Radiohead', 57508, '2Mex'),
#  (3840, 'Radiohead', 100752, '2Pac'),
#  (3840, 'Radiohead', 64706, '3T'),
#  (3840, 'Radiohead', 217492, '40 Thevz'),
#  (3840, 'Radiohead', 101746, '4th Disciple'),
#  (3840, 'Radiohead', 6014, '4th Measure Men'),
#  (3840, 'Radiohead', 79578, '50 Cent')]

# %% [markdown]
# The problem with this approach is that the query *structure* depends on the number of hops you want to permit.
#
# The query from the question, however, is independent of this number. You can just change `X` and leave the rest as it is. The trick is that it is a *recursive* SQL statement. Roughly speaking, a recursive statement consists of a base case statement connected via ```UNION``` (a concatenation of relations) with a statement the refers to the original statement. The recursive statement is executed recursively until it produces an empty result.
#
# The query uses this mechanism to write ```X_hop_collaborations``` (repeated in isolation below): its base case are the direct `collaborations`. Each iteration joins the `collaborations` relation to find artists within one more hop for each artist already found. It keeps track of the distance from the original post by incrementing the value of ```distance``` by one in each iteration. When that attribute reaches the value of ```X```, no records are produced by the recursive case, so recursion ends.
#
# Consider: we have to join `collaborations` with an exponentially growing relation for each hop. In addition to the query being difficult to write, it becomes very inefficient as `X` increases.

# %% [markdown]
# ### QUIZ EXERCISES

# %% [markdown]
# Q.1

# %%
# %%sql
# SELECT AVG(CAST(duration AS FLOAT))
# FROM tracks;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 1 rows affected.
# [(324.59572773212363,)]

# %% [markdown]
# Q.2

# %%
# %%sql
# SELECT table_name, column_name, data_type, is_nullable, ordinal_position
# FROM information_schema.columns
# WHERE table_schema = 'public'
# AND table_name NOT LIKE 'pg_%'
# ORDER BY table_name, ordinal_position;
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 17 rows affected.
# [('artists', 'artist_id', 'integer', 'NO', 1),
#  ('artists', 'name', 'character varying', 'YES', 2),
#  ('artists', 'realname', 'text', 'YES', 3),
#  ('artists', 'profile', 'text', 'YES', 4),
#  ('artists', 'url', 'text', 'YES', 5),
#  ('released_by', 'release_id', 'integer', 'NO', 1),
#  ('released_by', 'artist_id', 'integer', 'NO', 2),
#  ('releases', 'release_id', 'integer', 'NO', 1),
#  ('releases', 'released', 'date', 'NO', 2),
#  ('releases', 'title', 'text', 'NO', 3),
#  ('releases', 'country', 'character varying', 'YES', 4),
#  ('releases', 'genre', 'character varying', 'NO', 5),
#  ('tracks', 'release_id', 'integer', 'NO', 1),
#  ('tracks', 'position', 'character varying', 'YES', 2),
#  ('tracks', 'title', 'text', 'YES', 3),
#  ('tracks', 'duration', 'integer', 'YES', 4),
#  ('tracks', 'track_id', 'integer', 'NO', 5)]

# %%
# %%sql
# Select artist_id
# FROM artists
# WHERE name = 'Radiohead'
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 1 rows affected.
# [(3840,)]

# %%
# %%sql
# select releases.title
# from artists
# where releases.title = 'Hail To The Thief'
# Out:
#  * postgresql://postgres:***@postgres:5432/discogs
# 6 rows affected.
# [('Hail To The Thief',),
#  ('Hail To The Thief',),
#  ('Hail To The Thief',),
#  ('Hail To The Thief',),
#  ('Hail To The Thief',),
#  ('Hail To The Thief',)]

# %% [markdown]
# %%sql
# select releases.title
# from artists
# where releases.title = 'Hail To The Thief'
